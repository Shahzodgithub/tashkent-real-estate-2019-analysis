# %% [markdown]
# <a href="https://colab.research.google.com/github/Shahzodgithub/tashkent-real-estate-2019-analysis/blob/main/tashkent_real_estate_2019.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
pip install openpyxl

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_excel('/content/sample_data/uybor.xlsx')
df.head(20)
# Out:
#                                               address  ...        lng
# 0   город Ташкент, Yunusobod район, Юнусабад 8-й к...  ...  69.281049
# 1   город Ташкент, Yakkasaroy район, 1-й тупик Шот...  ...  69.261104
# 2   город Ташкент, Chilonzor район, Чиланзар 2-й к...  ...  69.223683
# 3   город Ташкент, Chilonzor район, Чиланзар 9-й к...  ...  69.196862
# 4      город Ташкент, Chilonzor район, площадь Актепа  ...  69.210831
# 5   город Ташкент, Chilonzor район, Чиланзар 6-й к...  ...  69.211763
# 6         город Ташкент, Chilonzor район, Чиланзар-16  ...  69.200587
# 7         город Ташкент, Yakkasaroy район, Саламатина  ...  69.243137
# 8           город Ташкент, Uchtepa район, Чиланзар-21  ...  69.173765
# 9          город Ташкент, Chilonzor район, Чиланзар-8  ...  69.205802
# 10          город Ташкент, Uchtepa район, Чиланзар-14  ...  69.190901
# 11        город Ташкент, Chilonzor район, Чиланзар-20  ...  69.180471
# ...

# %% [markdown]
# df = pd.read_excel('../input/tashkent-real-estate-2019/uybor.xlsx')
# df.head(20)

# %% [markdown]
# # 1. **Qaysi hududda uylar narxi qimmat**

# %%
plt.figure(figsize=(13,10))
sns.barplot(data=df, x='district', y='price')
plt.xticks(rotation=90)
plt.title("Uylar narxlari hududlar bo'yicha")
plt.show()

# %% [markdown]
# # 2. Xonalar soni va narxi o'rtasidagi korrelyatsiya

# %%
plt.figure(figsize=(10,6))
sns.lineplot(data=df, x='rooms', y='price')
plt.title("Xonalar soni va narxi ")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='rooms', y='price', hue='level')
plt.show()

# %% [markdown]
# # 3. Xonalar o'lchami va narxi o'rtasidagi korrelyatsiya

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='size', y='price', hue='level')
sns.regplot(data=df, x='size', y='price')
plt.show()

# %% [markdown]
# # 4. Narxlar bo'yicha uylar soni

# %%
plt.figure(figsize=(12,8))
sns.histplot(data=df, x='price')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(16,10))
sns.displot(data=df, x='price', height=5,aspect=2, hue='level', multiple="stack")
plt.xticks(rotation=90)
plt.show()

# %%
sns.displot(data=df, x='lat',kind='kde', height=5)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(16,10))
sns.ecdfplot(data=df, x='size',hue='rooms')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.swarmplot(data=df, x='size', y='price')
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 66.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 94.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 93.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
fig, ax = plt.subplots(2, 2, figsize=(15,10))
fig.suptitle("Grafik 1")
sns.histplot(ax=ax[0, 0], data=df, x='lat',y='price')
sns.histplot(ax=ax[0, 1], data=df, x='size')
sns.histplot(ax=ax[1, 0], data=df, x='level')
sns.histplot(ax=ax[1, 1], data=df, x='lat')
plt.show()
